# %%
import json

# %%
data = '''{
    "name" : "Chuck",
    "phone" : {
        "type" : "intl",
        "number" : "+1 734 303 4456"
    },
    "email" : {
        "hide" : "yes"
    }
}'''

# %%
teste = {
    "users": [
        {
            "status": {
                "text": "@jazzychad I just bought one .__.",
             },
             "location": "San Francisco, California",
             "screen_name": "leahculver",
             "name": "Leah Culver",
         },
    ]
}

# %%
input = '''[
    {   "id" : "001",
        "x" : "2",
        "name" : "chuck"
    } ,
    {   "id" : "009",
        "x" : "7",
        "name" : "chuck"
    }
]'''

# %%
info = json.loads(data)
print('Name:',info["name"])
print('hide:',info["email"]["hide"])
# Out:
# Name: Chuck
# hide: yes

# %%
info = json.loads(input)
print("User count:", len(info),"\n")
for item in info:
    print('Name', item['name'])
    print('Id',item['id'])
    print('Attribute',item['x'],'\n')
# Out:
# User count: 2
#
# Name chuck
# Id 001
# Attribute 2
#
# Name chuck
# Id 009
# Attribute 7

# %%
print(teste['users']['name'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_166852/774361129.py in <module>
# ----> 1 print(teste['name'])
#
# KeyError: 'name'
